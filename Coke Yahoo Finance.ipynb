# %%
import yfinance as yf

KO = yf.Ticker("KO")
# Out:
# <bound method TickerBase.get_balance_sheet of yfinance.Ticker object <KO>>

# %%
KO.financials
# Out:
#                                            2021-12-31     2020-12-31  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       12425000000.0   9749000000.0
# Minority Interest                        1861000000.0   1985000000.0
# Net Income                               9771000000.0   7747000000.0
# Selling General Administrative          11984000000.0   9579000000.0
# Gross Profit                            23298000000.0  19581000000.0
# Ebit                                    11321000000.0   9990000000.0
# Operating Income                        11321000000.0   9990000000.0
# Other Operating Expenses                   -7000000.0     12000000.0
# Interest Expense                        -1597000000.0  -1437000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
KO.balance_sheet
# Out:
#                                     2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets                 1.525000e+10  1.104400e+10  1.000200e+10
# Capital Surplus                   1.811600e+10  1.760100e+10  1.715400e+10
# Total Liab                        6.949400e+10  6.601200e+10  6.528300e+10
# Total Stockholder Equity          2.299900e+10  1.929900e+10  1.898100e+10
# Minority Interest                 1.861000e+09  1.985000e+09  2.117000e+09
# Other Current Liab                1.859000e+09  2.010000e+09  1.636000e+09
# Total Assets                      9.435400e+10  8.729600e+10  8.638100e+10
# Common Stock                      1.760000e+09  1.760000e+09  1.760000e+09
# Other Current Assets              1.018000e+09  1.520000e+08  5.700000e+07
# Retained Earnings                 6.909400e+10  6.655500e+10  6.585500e+10
# Other Liab                        1.025300e+10  9.986000e+09  9.662000e+09
# ...

# %%
cashflow = KO.cashflow
cashflow = pd.DataFrame(cashflow)
cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                                1.029000e+09  2.520000e+08
# Change To Liabilities                      2.843000e+09 -8.600000e+08
# Total Cashflows From Investing Activities -2.765000e+09 -1.477000e+09
# Net Borrowings                             2.280000e+08 -1.862000e+09
# Total Cash From Financing Activities      -6.786000e+09 -8.070000e+09
# Change To Operating Activities            -5.920000e+08  5.850000e+08
# Issuance Of Stock                          7.020000e+08  6.470000e+08
# Net Income                                 9.771000e+09  7.747000e+09
# Change In Cash                             2.915000e+09  3.730000e+08
# Repurchase Of Stock                       -1.110000e+08 -1.180000e+08
# Effect Of Exchange Rate                   -1.590000e+08  7.600000e+07
# Total Cash From Operating Activities       1.262500e+10  9.844000e+09
# ...

# %%
net = cashflow[cashflow.index == 'Net Income']
net
# Out:
#               2021-12-31    2020-12-31    2019-12-31    2018-12-31
# Net Income  9.771000e+09  7.747000e+09  8.920000e+09  6.434000e+09

# %%
data = yf.download("KO", start="2009-01-01", end="2019-12-31",
                   group_by="ticker")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2008-12
%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":["2008-12-31T00:00:00","2009-01-02T00:00:00","2009-01-05T00:00:00","2009-01-06T00:00:00","2009-01-07T00:00:00","2009-01-08T00:00:00","2009-01-09T00:00:00","2009-01-12T00:00:00","2009-01-13T00:00:00","2009-01-14T00:00:00","2009-01-15T00:00:00","2009-01-16T00:00:00","2009-01-20T00:00:0
# ...

# %%
px.line(df, y='Adj Close')
# Out:
# <div>                            <div id="7f06fee3-6ae5-45c2-9a6f-108496632036" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f06fee3-6ae5-45c2-9a6f-108496632036")) {                    Plotly.newPlot(                        "7f06fee3-6ae5-45c2-9a6f-108496632036",                        [{"hovertemplate":"Date=%{x}<br>Adj Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":["2008-12-31T00:00:00","2009-01-02T00:00:00","2009-01-05T00:00:00","2009-01-06T00:00:00","2009-01-07T00:00:00","2009-01-08T00:00:00","2009-01-09T00:00:00","2009-01-12T00:00:00","2009-01-13T00:00:00","2009-01-14T00:00:00","2009-01-15T00:00:00","2009-01-16T00:00:00","2009-01-20T00
# ...

# %%
px.line(df, y='High')
# Out:
# <div>                            <div id="e8d7553f-2fe3-4247-a59c-c43b14f53095" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8d7553f-2fe3-4247-a59c-c43b14f53095")) {                    Plotly.newPlot(                        "e8d7553f-2fe3-4247-a59c-c43b14f53095",                        [{"hovertemplate":"Date=%{x}<br>High=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":["2008-12-31T00:00:00","2009-01-02T00:00:00","2009-01-05T00:00:00","2009-01-06T00:00:00","2009-01-07T00:00:00","2009-01-08T00:00:00","2009-01-09T00:00:00","2009-01-12T00:00:00","2009-01-13T00:00:00","2009-01-14T00:00:00","2009-01-15T00:00:00","2009-01-16T00:00:00","2009-01-20T00:00:0
# ...

# %%
px.line(df, y='Volume')
# Out:
# <div>                            <div id="28c21116-3787-4f72-b317-564068e3ec8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28c21116-3787-4f72-b317-564068e3ec8d")) {                    Plotly.newPlot(                        "28c21116-3787-4f72-b317-564068e3ec8d",                        [{"hovertemplate":"Date=%{x}<br>Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":["2008-12-31T00:00:00","2009-01-02T00:00:00","2009-01-05T00:00:00","2009-01-06T00:00:00","2009-01-07T00:00:00","2009-01-08T00:00:00","2009-01-09T00:00:00","2009-01-12T00:00:00","2009-01-13T00:00:00","2009-01-14T00:00:00","2009-01-15T00:00:00","2009-01-16T00:00:00","2009-01-20T00:00
# ...

# %%
# show revenues
revenue = KO.financials.loc['Total Revenue']
px.bar(x=revenue.index, y=revenue.values, title='Total Revenues')
# Out:
# <div>                            <div id="2d55774e-614c-4b1e-8d5a-5dd9fa7213ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d55774e-614c-4b1e-8d5a-5dd9fa7213ca")) {                    Plotly.newPlot(                        "2d55774e-614c-4b1e-8d5a-5dd9fa7213ca",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["2021-12-31T00:00:00","2020-12-31T00:00:00","2019-12-31T00:00:00","2018-12-31T00:00:00"],"xaxis":"x","y":[38655000000.0,33014000000.0,37266000000.0,34300000000.0],"yaxis":"y"}],                        {"barmode":"relati
# ...

# %%
EBIT = KO.financials.loc['Ebit']
px.bar(x=EBIT.index, y=EBIT.values, title='EBIT')
# Out:
# <div>                            <div id="1d0f6afd-4cc3-469d-a048-c68e0da360d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d0f6afd-4cc3-469d-a048-c68e0da360d9")) {                    Plotly.newPlot(                        "1d0f6afd-4cc3-469d-a048-c68e0da360d9",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["2021-12-31T00:00:00","2020-12-31T00:00:00","2019-12-31T00:00:00","2018-12-31T00:00:00"],"xaxis":"x","y":[11321000000.0,9990000000.0,10625000000.0,10203000000.0],"yaxis":"y"}],                        {"barmode":"relativ
# ...

# %%
KO.info
# Out:
# {'zip': '30313',
#  'sector': 'Consumer Defensive',
#  'fullTimeEmployees': 79000,
# ...

# %%
# get price to book
pb = KO.info['priceToBook']
pe = KO.info['regularMarketPrice']/KO.info['trailingEps']
print('Price to Book Ratio is: %.2f' % pb)
print('Price to Earnings Ratio is: %.2f' % pe)
# Out:
# Price to Book Ratio is: 11.82
# Price to Earnings Ratio is: 27.94

# %%
KO.recommendations
# Out:
#                                 Firm    To Grade From Grade Action
# Date
# 2012-02-08 13:03:00              UBS                          main
# 2012-04-03 08:15:00  Stifel Nicolaus        Hold              down
# 2012-04-12 06:15:00    Deutsche Bank         Buy              main
# 2012-04-18 11:40:00              UBS     Neutral              main
# 2012-08-13 09:29:00    Goldman Sachs     Neutral        Buy   down
# ...                              ...         ...        ...    ...
# 2022-01-04 12:18:42       Guggenheim         Buy    Neutral     up
# 2022-02-08 17:03:48   Morgan Stanley  Overweight              main
# 2022-02-11 13:06:18   Morgan Stanley  Overweight              main
# 2022-02-11 15:31:33    Deutsche Bank        Hold              main
# 2022-03-30 12:06:09        JP Morgan  Overweight              main
#
# [156 rows x 4 columns]

# %%
KO.institutional_holders
# Out:
#                                        Holder     Shares Date Reported  \
# 0                     Berkshire Hathaway, Inc  400000000    2021-12-30
# 1                  Vanguard Group, Inc. (The)  342258418    2021-12-30
# 2                              Blackrock Inc.  279741946    2021-12-30
# 3                    State Street Corporation  170597908    2021-12-30
# 4            Wellington Management Group, LLP   72853801    2021-12-30
# 5               Geode Capital Management, LLC   69443905    2021-12-30
# 6                                    FMR, LLC   67555066    2021-12-30
# 7                   JP Morgan Chase & Company   60991218    2021-12-30
# 8                              Morgan Stanley   52415748    2021-12-30
# 9  Charles Schwab Investment Management, Inc.   50269019    2021-12-30
#
#     % Out        Value
# 0  0.0923  23684000000
# 1  0.0790  20265120929
# 2  0.0645  16563520622
# 3  0.0394  10101102132
# 4  0.0168   4313673557
# 5  0.0160   4111773615
# ...

# %%
KO.calendar
# Out:
#                                 Value
# Earnings Date     2022-04-25 12:30:00
# Earnings Average                 0.58
# Earnings Low                     0.54
# Earnings High                    0.61
# Revenue Average            9816150000
# Revenue Low                9571000000
# Revenue High              10063000000

# %%
KO.major_holders
# Out:
#         0                                      1
# 0   0.67%        % of Shares Held by All Insider
# 1  70.37%       % of Shares Held by Institutions
# 2  70.84%        % of Float Held by Institutions
# 3    3361  Number of Institutions Holding Shares

# %%
KO.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1962-03-13   0.001563           0.0
# 1962-06-11   0.001563           0.0
# 1962-09-11   0.001563           0.0
# 1962-11-28   0.001563           0.0
# 1963-03-11   0.001758           0.0
# ...               ...           ...
# 2021-03-12   0.420000           0.0
# 2021-06-14   0.420000           0.0
# 2021-09-14   0.420000           0.0
# 2021-11-30   0.420000           0.0
# 2022-03-14   0.440000           0.0
#
# [249 rows x 2 columns]

# %%
from yahoofinancials import YahooFinancials

# %%
ticker = 'KO'
yahoo_financials = YahooFinancials(ticker)

# %%
yahoo_financials.get_financial_stmts('annual', 'balance')
# Out:
# {'balanceSheetHistory': {'KO': [{'2021-12-31': {'intangibleAssets': 15250000000,
#      'capitalSurplus': 18116000000,
#      'totalLiab': 69494000000,
#      'totalStockholderEquity': 22999000000,
#      'minorityInterest': 1861000000,
#      'otherCurrentLiab': 1859000000,
#      'totalAssets': 94354000000,
#      'commonStock': 1760000000,
#      'otherCurrentAssets': 1018000000,
#      'retainedEarnings': 69094000000,
#      'otherLiab': 10253000000,
#      'goodWill': 19363000000,
#      'treasuryStock': -65971000000,
#      'otherAssets': 5318000000,
#      'cash': 9684000000,
#      'totalCurrentLiabilities': 19950000000,
#      'deferredLongTermAssetCharges': 2129000000,
#      'shortLongTermDebt': 1338000000,
#      'otherStockholderEquity': -14330000000,
#      'propertyPlantEquipment': 11338000000,
#      'totalCurrentAssets': 22545000000,
#      'longTermInvestments': 20540000000,
#      'netTangibleAssets': -11614000000,
#      'shortTermInvestments': 2941000000,
# ...

# %%
yahoo_financials.get_key_statistics_data()
# Out:
# {'KO': {'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 7.918,
#   'beta3Year': None,
#   'profitMargins': 0.25277,
#   'enterpriseToEbitda': 23.961,
#   '52WeekChange': 0.17578495,
#   'morningStarRiskRating': None,
#   'forwardEps': 2.64,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 4335470080,
#   'fundInceptionDate': '-',
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 5.318,
#   'sharesShort': 25129766,
#   'sharesPercentSharesOut': 0.0058,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.7037,
#   'netIncomeToCommon': 9770999808,
#   'trailingEps': 2.25,
#   'lastDividendValue': 0.44,
#   'SandP52WeekChange': 0.12486684,
#   'priceToBook': 11.76006,
#   'heldPercentInsiders': 0.00669,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1640908800,
#   'shortRatio': 1.2,
#   'sharesShortPreviousMonthDate': '2022-02-15',
# ...

# %%
yahoo_financials.get_50day_moving_avg()
# Out:
# 60.9572
